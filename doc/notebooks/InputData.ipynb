# %%
# %matplotlib ipympl
from helita.sim import rh15d, rh15d_vis

# %% [markdown]
# Now we need to be in the directory where we have the RH 1.5D atmosphere files. You can change the line below to a directory in your computer.

# %%
cd ~/codes/rh/Atmos
# Out:
# /Users/tiago/codes/rh/Atmos

# %% [markdown]
# ## 1. Input atmosphere visualisation
#
# One can explore the input atmosphere using a function from `helita.sim.rh15d_vis`. Enter the file name as argument:

# %%
rh15d_vis.InputAtmosphere('FALC_82_5x5.hdf5');
